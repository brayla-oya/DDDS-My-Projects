# %% [markdown]
# <a href="https://colab.research.google.com/github/brayla-oya/DDDS-My-Projects/blob/main/EV_merged.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Collection/Sources

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# EV_users
url = 'https://raw.githubusercontent.com/SPLearning27/DDDS-My-Projects/main/Capstone-Project/ev_data.csv'
ev_users = pd.read_csv(url)
ev_users
# Out:
#       Registration Date  ZIP Code  Vehicle Count  Registration Year
# 0            2022-03-01     87106              1               2022
# 1            2019-03-01     88101              1               2019
# 2            2023-09-01     87501              1               2023
# 3            2019-09-01     87120              1               2019
# 4            2019-12-01     87547              1               2019
# ...                 ...       ...            ...                ...
# 18342        2023-08-01     87505              2               2023
# 18343        2023-08-01     87507              2               2023
# 18344        2023-08-01     87112              2               2023
# 18345        2023-08-01     87120              2               2023
# 18346        2023-08-01     87122              2               2023
#
# [18347 rows x 4 columns]

# %%
ev_users.rename(columns={'ZIP Code': 'ZIP'}, inplace=True)
ev_users
# Out:
#       Registration Date    ZIP  Vehicle Count  Registration Year
# 0            2022-03-01  87106              1               2022
# 1            2019-03-01  88101              1               2019
# 2            2023-09-01  87501              1               2023
# 3            2019-09-01  87120              1               2019
# 4            2019-12-01  87547              1               2019
# ...                 ...    ...            ...                ...
# 18342        2023-08-01  87505              2               2023
# 18343        2023-08-01  87507              2               2023
# 18344        2023-08-01  87112              2               2023
# 18345        2023-08-01  87120              2               2023
# 18346        2023-08-01  87122              2               2023
#
# [18347 rows x 4 columns]

# %%
ev_users['ZIP'] = ev_users['ZIP'].astype(str).str.zfill(5)

# %%
abq_zips = [
    '87102', '87104', '87105', '87106', '87107',
    '87108', '87109', '87110', '87111', '87112',
    '87113', '87114', '87120', '87121', '87122',
    '87123'
]

ev_users_abq = ev_users[ev_users['ZIP'].isin(abq_zips)]
ev_users_abq
# Out:
#       Registration Date    ZIP  Vehicle Count  Registration Year
# 0            2022-03-01  87106              1               2022
# 3            2019-09-01  87120              1               2019
# 5            2024-03-01  87113              1               2024
# 7            2025-03-01  87111              1               2025
# 8            2025-01-01  87106              1               2025
# ...                 ...    ...            ...                ...
# 18339        2023-08-01  87111              2               2023
# 18341        2023-08-01  87113              2               2023
# 18344        2023-08-01  87112              2               2023
# 18345        2023-08-01  87120              2               2023
# 18346        2023-08-01  87122              2               2023
#
# [7999 rows x 4 columns]

# %%
# Change Registration to just Year
ev_users_zip = ev_users_abq.rename(columns={'Registration Year': 'Year'})
ev_users_zip
# Out:
#       Registration Date    ZIP  Vehicle Count  Year
# 0            2022-03-01  87106              1  2022
# 3            2019-09-01  87120              1  2019
# 5            2024-03-01  87113              1  2024
# 7            2025-03-01  87111              1  2025
# 8            2025-01-01  87106              1  2025
# ...                 ...    ...            ...   ...
# 18339        2023-08-01  87111              2  2023
# 18341        2023-08-01  87113              2  2023
# 18344        2023-08-01  87112              2  2023
# 18345        2023-08-01  87120              2  2023
# 18346        2023-08-01  87122              2  2023
#
# [7999 rows x 4 columns]

# %%
# Group by 'registration year' and 'ZIP', then sum the 'vehicle count' column
ev_users_zip = ev_users_zip.groupby(['Year', 'ZIP'])['Vehicle Count'].sum().reset_index()
ev_users_zip
# Out:
#      Year    ZIP  Vehicle Count
# 0    2010  87106              2
# 1    2012  87106             11
# 2    2014  87106              4
# 3    2014  87109              1
# 4    2014  87120              1
# ..    ...    ...            ...
# 176  2025  87114            187
# 177  2025  87120            228
# 178  2025  87121             85
# 179  2025  87122            151
# 180  2025  87123            106
#
# [181 rows x 3 columns]

# %%
# EV chargers
url2 = 'https://raw.githubusercontent.com/brayla-oya/DDDS-My-Projects/main/ev_zip_ABQ%20(1).csv'
ev_charge = pd.read_csv(url2)
ev_charge
# Out:
#       ZIP Status Code   Latitude   Longitude  EV Connector Types  \
# 0   87107           E  35.108486 -106.612804               TESLA
# 1   87107           E  35.112740 -106.606260  CHADEMO J1772COMBO
# 2   87116           E  35.052600 -106.533285    J1772 J1772COMBO
# 3   87113           E  35.183643 -106.589520          J1772COMBO
# 4   87110           E  35.104286 -106.565888               TESLA
# 5   87110           E  35.096985 -106.564983  CHADEMO J1772COMBO
# 6   87109           E  35.171800 -106.586601               TESLA
# 7   87106           E  35.075580 -106.621750          J1772COMBO
# 8   87114           E  35.188294 -106.661535  CHADEMO J1772COMBO
# 9   87114           E  35.188312 -106.661583    J1772COMBO TESLA
# 10  87109           E  35.164463 -106.585263  CHADEMO J1772COMBO
# 11  87109           E  35.164492 -106.585378  CHADEMO J1772COMBO
# 12  87109           E  35.164510 -106.585433  CHADEMO J1772COMBO
# 13  87109           E  35.164495 -106.585402  CHADEMO J1772COMBO
# 14  87107           E  35.136565 -106.620698          J1772COMBO
# 15  87108           E  35.058535 -106.582530          J1772COMBO
# 16  87107           E  35.108766 -106.614189          J1772COMBO
# 17  87123           E  35.069285 -106.541498          J1772COMBO
# 18  87109           E  35.137337 -106.583863          J1772COMBO
# 19  87110           T  35.087638 -106.555371          J1772COMBO
# 20  87108           E  35.086861 -106.565661          J1772COMBO
# 21  87110           T  35.087082 -106.564699          J1772COMBO
# 22  87110           E  35.103820 -106.565700          J1772COMBO
# 23  87105           E  35.079000 -106.745150          J1772COMBO
# 24  87110           E  35.103758 -106.565638          J1772COMBO
#
#     EV DC Fast Count  Open Year
# 0                6.0     2015.0
# 1               10.0     2019.0
# 2                5.0     2020.0
# 3                1.0     2021.0
# 4               16.0     2022.0
# 5                2.0     2023.0
# 6                8.0     2023.0
# 7                6.0     2023.0
# 8                1.0     2024.0
# 9                1.0     2024.0
# 10               1.0     2024.0
# 11               1.0     2024.0
# 12               1.0     2024.0
# 13               1.0     2024.0
# 14               4.0     2024.0
# 15               6.0     2024.0
# 16               4.0     2025.0
# 17               2.0     2025.0
# 18               2.0     2025.0
# 19               2.0     2024.0
# 20               4.0     2024.0
# 21               2.0     2024.0
# 22               6.0     2025.0
# 23               4.0     2025.0
# 24               6.0     2025.0

# %%
ev_charge['ZIP'] = ev_charge['ZIP'].astype(str).str.zfill(5)

# %%
# Group by 'Open Year' and 'ZIP', then sum the '# of EV chargers' column
ev_charge_zip = ev_charge.groupby(['Open Year', 'ZIP'])['EV DC Fast Count'].sum().reset_index()
ev_charge_zip
# Out:
#     Open Year    ZIP  EV DC Fast Count
# 0      2015.0  87107               6.0
# 1      2019.0  87107              10.0
# 2      2020.0  87116               5.0
# 3      2021.0  87113               1.0
# 4      2022.0  87110              16.0
# 5      2023.0  87106               6.0
# 6      2023.0  87109               8.0
# 7      2023.0  87110               2.0
# 8      2024.0  87107               4.0
# 9      2024.0  87108              10.0
# 10     2024.0  87109               4.0
# 11     2024.0  87110               4.0
# 12     2024.0  87114               2.0
# 13     2025.0  87105               4.0
# 14     2025.0  87107               4.0
# 15     2025.0  87109               2.0
# 16     2025.0  87110              12.0
# 17     2025.0  87123               2.0

# %%
# Change Year to string
ev_charge_zip['Open Year'] = ev_charge_zip['Open Year'].astype('Int64')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Open Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-433561818.py in <cell line: 0>()
#       1 # Change Year to string
# ----> 2 ev_charge_zip['Open Year'] = ev_charge_zip['Open Year'].astype('Int64')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Open Year'

# %%
# Change Open Year to just Year
ev_charge_zip = ev_charge_zip.rename(columns={'Open Year': 'Year'})
ev_charge_zip
# Out:
#     Year    ZIP  EV DC Fast Count
# 0   2015  87107               6.0
# 1   2019  87107              10.0
# 2   2020  87116               5.0
# 3   2021  87113               1.0
# 4   2022  87110              16.0
# 5   2023  87106               6.0
# 6   2023  87109               8.0
# 7   2023  87110               2.0
# 8   2024  87107               4.0
# 9   2024  87108              10.0
# 10  2024  87109               4.0
# 11  2024  87110               4.0
# 12  2024  87114               2.0
# 13  2025  87105               4.0
# 14  2025  87107               4.0
# 15  2025  87109               2.0
# 16  2025  87110              12.0
# 17  2025  87123               2.0

# %%
ev2 = ev_charge_zip.sort_values(by='Year').groupby('ZIP') ['EV DC Fast Count'].cumsum()

# %%
ev2.size
# Out:
# 18

# %%
ev_charge_zip.shape
# Out:
# (18, 3)

# %%
pd.concat([ev_charge_zip.sort_values(by='Year'),ev2],axis=1).sort_values(by=['ZIP','Year'])
# Out:
#     Year    ZIP  EV DC Fast Count  EV DC Fast Count
# 13  2025  87105               4.0               4.0
# 5   2023  87106               6.0               6.0
# 0   2015  87107               6.0               6.0
# 1   2019  87107              10.0              16.0
# 8   2024  87107               4.0              20.0
# 14  2025  87107               4.0              24.0
# 9   2024  87108              10.0              10.0
# 6   2023  87109               8.0               8.0
# 10  2024  87109               4.0              12.0
# 15  2025  87109               2.0              14.0
# 4   2022  87110              16.0              16.0
# 7   2023  87110               2.0              18.0
# 11  2024  87110               4.0              22.0
# 16  2025  87110              12.0              34.0
# 3   2021  87113               1.0               1.0
# 12  2024  87114               2.0               2.0
# 2   2020  87116               5.0               5.0
# 17  2025  87123               2.0               2.0

# %%
# EV Businesses
url3 = 'https://raw.githubusercontent.com/SPlearning27/DDDS-My-Projects/main/Capstone-Project/biz_data.csv'
ev_biz = pd.read_csv(url3)
ev_biz
# Out:
#        STATUS TYPEABBREVIATION    ZIP    Year
# 0      Active              BRC  87109  2012.0
# 1      Active              BRC  87109  2011.0
# 2      Active              BRC  87123  2025.0
# 3      Active              BRC  87120  2016.0
# 4      Active              BRC  87105  2008.0
# ...       ...              ...    ...     ...
# 14898  Active              COM  87112  2025.0
# 14899  Active               HB  87105  2025.0
# 14900  Active               HB  87102  2025.0
# 14901  Active               HB  87107  2025.0
# 14902  Active               HB  87107  2025.0
#
# [14903 rows x 4 columns]

# %%
ev_biz['ZIP'] = ev_biz['ZIP'].astype(str).str.zfill(5)

# %%
ev_biz = ev_biz.rename(columns={'TYPEABBREVIATION': 'Business Type'})

# %%
# Change Year to string
ev_biz['Year'] = ev_biz['Year'].astype('Int64')

# %%
ev_biz
# Out:
#        STATUS Business Type    ZIP  Year
# 0      Active           BRC  87109  2012
# 1      Active           BRC  87109  2011
# 2      Active           BRC  87123  2025
# 3      Active           BRC  87120  2016
# 4      Active           BRC  87105  2008
# ...       ...           ...    ...   ...
# 14898  Active           COM  87112  2025
# 14899  Active            HB  87105  2025
# 14900  Active            HB  87102  2025
# 14901  Active            HB  87107  2025
# 14902  Active            HB  87107  2025
#
# [14903 rows x 4 columns]

# %%
# Group by 'YEAR' and 'ZIP', then count the number of businesses in each group
ev_biz_zip = ev_biz.groupby([ 'ZIP', 'Year']).size().cumsum()
# .reset_index(name='Business Count').sort_values(by=['ZIP', 'Year'])
ev_biz_zip
# Out:
# ZIP    Year
# 87102  2003       12
#        2004       24
#        2005       37
#        2006       43
#        2007       44
#                ...
# 87131  2011    14895
#        2016    14897
#        2019    14898
#        2020    14899
#        2025    14903
# Length: 386, dtype: int64

# %%
ev_biz_zip
# Out:
#      Year    ZIP Business Type  Business Count
# 0    2003  87102           BRC              12
# 1    2003  87104           BRC               6
# 2    2003  87105           BRC              54
# 3    2003  87106           BRC              11
# 4    2003  87107           BRC              20
# ..    ...    ...           ...             ...
# 484  2025  87131           COM               3
# 485  2026  87105           COM               1
# 486  2026  87110           BRC               1
# 487  2026  87113           BRC               1
# 488  2026  87121           BRC               1
#
# [489 rows x 4 columns]

# %%
# Business Count
business_count = ev_biz_zip.groupby("ZIP").size().reset_index(name='Business Count')
business_count
# Out:
#       ZIP  Business Count
# 0   87102              31
# 1   87104              27
# 2   87105              37
# 3   87106              27
# 4   87107              34
# 5   87108              27
# 6   87109              27
# 7   87110              30
# 8   87111              27
# 9   87112              27
# 10  87113              29
# 11  87114              32
# 12  87115               1
# 13  87116              10
# 14  87120              27
# 15  87121              34
# 16  87122              29
# 17  87123              26
# 18  87131               7

# %%
ev_users_zip
# Out:
#      Year    ZIP  Vehicle Count
# 0    2010  87106              2
# 1    2012  87106             11
# 2    2014  87106              4
# 3    2014  87109              1
# 4    2014  87120              1
# ..    ...    ...            ...
# 176  2025  87114            187
# 177  2025  87120            228
# 178  2025  87121             85
# 179  2025  87122            151
# 180  2025  87123            106
#
# [181 rows x 3 columns]

# %%
ev_charge_zip
# Out:
#     Year    ZIP  EV DC Fast Count
# 0   2015  87107               6.0
# 1   2019  87107              10.0
# 2   2020  87116               5.0
# 3   2021  87113               1.0
# 4   2022  87110              16.0
# 5   2023  87106               6.0
# 6   2023  87109               8.0
# 7   2023  87110               2.0
# 8   2024  87107               4.0
# 9   2024  87108              10.0
# 10  2024  87109               4.0
# 11  2024  87110               4.0
# 12  2024  87114               2.0
# 13  2025  87105               4.0
# 14  2025  87107               4.0
# 15  2025  87109               2.0
# 16  2025  87110              12.0
# 17  2025  87123               2.0

# %%
# EV users and ev chargers
ev_merge1 = pd.merge(ev_users_zip, ev_charge_zip, on=['ZIP', 'Year'], how='inner').sort_values(by=['ZIP', 'Year'])
ev_merge1
# Out:
#     Year    ZIP  Vehicle Count  EV DC Fast Count
# 12  2025  87105             51               4.0
# 4   2023  87106            191               6.0
# 0   2015  87107              2               6.0
# 1   2019  87107             24              10.0
# 7   2024  87107            166               4.0
# 13  2025  87107            122               4.0
# 8   2024  87108             82              10.0
# 5   2023  87109            100               8.0
# 9   2024  87109            139               4.0
# 14  2025  87109             98               2.0
# 3   2022  87110             73              16.0
# 6   2023  87110            125               2.0
# 10  2024  87110            148               4.0
# 15  2025  87110             94              12.0
# 2   2021  87113             31               1.0
# 11  2024  87114            279               2.0
# 16  2025  87123            106               2.0

# %%
final_ev_merge = pd.merge(ev_merge1, ev_biz_zip, on=['ZIP', 'Year'], how='inner')
final_ev_merge
# Out:
#     Year    ZIP  Vehicle Count  EV DC Fast Count Business Type  Business Count
# 0   2015  87107              2               6.0           BRC              26
# 1   2019  87107             24              10.0           BRC             110
# 2   2019  87107             24              10.0           COM               1
# 3   2019  87107             24              10.0            HB               1
# 4   2021  87113             31               1.0           BRC               8
# 5   2021  87113             31               1.0            HB               1
# 6   2022  87110             73              16.0           BRC               5
# 7   2023  87106            191               6.0           BRC               6
# 8   2023  87109            100               8.0           BRC               9
# 9   2023  87110            125               2.0           BRC              17
# 10  2024  87107            166               4.0           BRC              53
# 11  2024  87107            166               4.0           COM               4
# 12  2024  87107            166               4.0            HB               3
# 13  2024  87108             82              10.0           BRC              30
# 14  2024  87108             82              10.0            HB               1
# 15  2024  87109            139               4.0           BRC              44
# 16  2024  87109            139               4.0           COM               2
# 17  2024  87110            148               4.0           BRC              56
# 18  2024  87110            148               4.0           COM               3
# 19  2024  87114            279               2.0           BRC              22
# 20  2024  87114            279               2.0           COM               2
# 21  2024  87114            279               2.0            HB               7
# 22  2025  87105             51               4.0           BRC             105
# 23  2025  87105             51               4.0           COM              30
# 24  2025  87105             51               4.0            HB             131
# 25  2025  87107            122               4.0           BRC             311
# 26  2025  87107            122               4.0           COM              33
# 27  2025  87107            122               4.0            HB              27
# 28  2025  87109             98               2.0           BRC             378
# 29  2025  87109             98               2.0           COM              19
# 30  2025  87109             98               2.0            HB               1
# 31  2025  87110             94              12.0           BRC             368
# 32  2025  87110             94              12.0           COM              26
# 33  2025  87110             94              12.0            CR               1
# 34  2025  87110             94              12.0            HB               5
# 35  2025  87123            106               2.0           BRC              90
# 36  2025  87123            106               2.0           COM               3
# 37  2025  87123            106               2.0            HB               2

# %%
# Calculate EV-to-charger ratio
final_ev_merge["EV Per Charger"] = final_ev_merge["Vehicle Count"] / final_ev_merge["EV DC Fast Count"]
final_ev_merge
# Out:
#     Year    ZIP  Vehicle Count  EV DC Fast Count Business Type  \
# 0   2015  87107              2               6.0           BRC
# 1   2019  87107             24              10.0           BRC
# 2   2019  87107             24              10.0           COM
# 3   2019  87107             24              10.0            HB
# 4   2021  87113             31               1.0           BRC
# 5   2021  87113             31               1.0            HB
# 6   2022  87110             73              16.0           BRC
# 7   2023  87106            191               6.0           BRC
# 8   2023  87109            100               8.0           BRC
# 9   2023  87110            125               2.0           BRC
# 10  2024  87107            166               4.0           BRC
# 11  2024  87107            166               4.0           COM
# 12  2024  87107            166               4.0            HB
# 13  2024  87108             82              10.0           BRC
# 14  2024  87108             82              10.0            HB
# 15  2024  87109            139               4.0           BRC
# 16  2024  87109            139               4.0           COM
# 17  2024  87110            148               4.0           BRC
# 18  2024  87110            148               4.0           COM
# 19  2024  87114            279               2.0           BRC
# 20  2024  87114            279               2.0           COM
# 21  2024  87114            279               2.0            HB
# 22  2025  87105             51               4.0           BRC
# 23  2025  87105             51               4.0           COM
# 24  2025  87105             51               4.0            HB
# 25  2025  87107            122               4.0           BRC
# 26  2025  87107            122               4.0           COM
# 27  2025  87107            122               4.0            HB
# 28  2025  87109             98               2.0           BRC
# 29  2025  87109             98               2.0           COM
# 30  2025  87109             98               2.0            HB
# 31  2025  87110             94              12.0           BRC
# 32  2025  87110             94              12.0           COM
# 33  2025  87110             94              12.0            CR
# 34  2025  87110             94              12.0            HB
# 35  2025  87123            106               2.0           BRC
# 36  2025  87123            106               2.0           COM
# 37  2025  87123            106               2.0            HB
#
#     Business Count  EV Per Charger
# 0               26        0.333333
# 1              110        2.400000
# 2                1        2.400000
# 3                1        2.400000
# 4                8       31.000000
# 5                1       31.000000
# 6                5        4.562500
# 7                6       31.833333
# 8                9       12.500000
# 9               17       62.500000
# 10              53       41.500000
# 11               4       41.500000
# 12               3       41.500000
# 13              30        8.200000
# 14               1        8.200000
# 15              44       34.750000
# 16               2       34.750000
# 17              56       37.000000
# 18               3       37.000000
# 19              22      139.500000
# 20               2      139.500000
# 21               7      139.500000
# 22             105       12.750000
# 23              30       12.750000
# 24             131       12.750000
# 25             311       30.500000
# 26              33       30.500000
# 27              27       30.500000
# 28             378       49.000000
# 29              19       49.000000
# 30               1       49.000000
# 31             368        7.833333
# 32              26        7.833333
# 33               1        7.833333
# 34               5        7.833333
# 35              90       53.000000
# 36               3       53.000000
# 37               2       53.000000

# %%
# Flag underserved ZIPs
final_ev_merge["Underserved"] = (final_ev_merge["EV Per Charger"] > final_ev_merge["EV Per Charger"].mean()) & (final_ev_merge["Business Count"] > final_ev_merge["Business Count"].mean())
final_ev_merge
# Out:
#     Year    ZIP  Vehicle Count  EV DC Fast Count Business Type  \
# 0   2015  87107              2               6.0           BRC
# 1   2019  87107             24              10.0           BRC
# 2   2019  87107             24              10.0           COM
# 3   2019  87107             24              10.0            HB
# 4   2021  87113             31               1.0           BRC
# 5   2021  87113             31               1.0            HB
# 6   2022  87110             73              16.0           BRC
# 7   2023  87106            191               6.0           BRC
# 8   2023  87109            100               8.0           BRC
# 9   2023  87110            125               2.0           BRC
# 10  2024  87107            166               4.0           BRC
# 11  2024  87107            166               4.0           COM
# 12  2024  87107            166               4.0            HB
# 13  2024  87108             82              10.0           BRC
# 14  2024  87108             82              10.0            HB
# 15  2024  87109            139               4.0           BRC
# 16  2024  87109            139               4.0           COM
# 17  2024  87110            148               4.0           BRC
# 18  2024  87110            148               4.0           COM
# 19  2024  87114            279               2.0           BRC
# 20  2024  87114            279               2.0           COM
# 21  2024  87114            279               2.0            HB
# 22  2025  87105             51               4.0           BRC
# 23  2025  87105             51               4.0           COM
# 24  2025  87105             51               4.0            HB
# 25  2025  87107            122               4.0           BRC
# 26  2025  87107            122               4.0           COM
# 27  2025  87107            122               4.0            HB
# 28  2025  87109             98               2.0           BRC
# 29  2025  87109             98               2.0           COM
# 30  2025  87109             98               2.0            HB
# 31  2025  87110             94              12.0           BRC
# 32  2025  87110             94              12.0           COM
# 33  2025  87110             94              12.0            CR
# 34  2025  87110             94              12.0            HB
# 35  2025  87123            106               2.0           BRC
# 36  2025  87123            106               2.0           COM
# 37  2025  87123            106               2.0            HB
#
#     Business Count  EV Per Charger  Underserved
# 0               26        0.333333        False
# 1              110        2.400000        False
# 2                1        2.400000        False
# 3                1        2.400000        False
# 4                8       31.000000        False
# 5                1       31.000000        False
# 6                5        4.562500        False
# 7                6       31.833333        False
# 8                9       12.500000        False
# 9               17       62.500000        False
# 10              53       41.500000         True
# 11               4       41.500000        False
# 12               3       41.500000        False
# 13              30        8.200000        False
# 14               1        8.200000        False
# 15              44       34.750000        False
# 16               2       34.750000        False
# 17              56       37.000000         True
# 18               3       37.000000        False
# 19              22      139.500000        False
# 20               2      139.500000        False
# 21               7      139.500000        False
# 22             105       12.750000        False
# 23              30       12.750000        False
# 24             131       12.750000        False
# 25             311       30.500000        False
# 26              33       30.500000        False
# 27              27       30.500000        False
# 28             378       49.000000         True
# 29              19       49.000000        False
# 30               1       49.000000        False
# 31             368        7.833333        False
# 32              26        7.833333        False
# 33               1        7.833333        False
# 34               5        7.833333        False
# 35              90       53.000000         True
# 36               3       53.000000        False
# 37               2       53.000000        False

# %%
# Sort to see top underserved areas
final_ev_merge.sort_values("EV Per Charger", ascending=False)
# Out:
#     Year    ZIP  Vehicle Count  EV DC Fast Count Business Type  \
# 19  2024  87114            279               2.0           BRC
# 21  2024  87114            279               2.0            HB
# 20  2024  87114            279               2.0           COM
# 9   2023  87110            125               2.0           BRC
# 36  2025  87123            106               2.0           COM
# 35  2025  87123            106               2.0           BRC
# 37  2025  87123            106               2.0            HB
# 30  2025  87109             98               2.0            HB
# 29  2025  87109             98               2.0           COM
# 28  2025  87109             98               2.0           BRC
# 10  2024  87107            166               4.0           BRC
# 12  2024  87107            166               4.0            HB
# 11  2024  87107            166               4.0           COM
# 17  2024  87110            148               4.0           BRC
# 18  2024  87110            148               4.0           COM
# 15  2024  87109            139               4.0           BRC
# 16  2024  87109            139               4.0           COM
# 7   2023  87106            191               6.0           BRC
# 5   2021  87113             31               1.0            HB
# 4   2021  87113             31               1.0           BRC
# 25  2025  87107            122               4.0           BRC
# 27  2025  87107            122               4.0            HB
# 26  2025  87107            122               4.0           COM
# 23  2025  87105             51               4.0           COM
# 24  2025  87105             51               4.0            HB
# 22  2025  87105             51               4.0           BRC
# 8   2023  87109            100               8.0           BRC
# 13  2024  87108             82              10.0           BRC
# 14  2024  87108             82              10.0            HB
# 33  2025  87110             94              12.0            CR
# 31  2025  87110             94              12.0           BRC
# 32  2025  87110             94              12.0           COM
# 34  2025  87110             94              12.0            HB
# 6   2022  87110             73              16.0           BRC
# 1   2019  87107             24              10.0           BRC
# 2   2019  87107             24              10.0           COM
# 3   2019  87107             24              10.0            HB
# 0   2015  87107              2               6.0           BRC
#
#     Business Count  EV Per Charger  Underserved
# 19              22      139.500000        False
# 21               7      139.500000        False
# 20               2      139.500000        False
# 9               17       62.500000        False
# 36               3       53.000000        False
# 35              90       53.000000         True
# 37               2       53.000000        False
# 30               1       49.000000        False
# 29              19       49.000000        False
# 28             378       49.000000         True
# 10              53       41.500000         True
# 12               3       41.500000        False
# 11               4       41.500000        False
# 17              56       37.000000         True
# 18               3       37.000000        False
# 15              44       34.750000        False
# 16               2       34.750000        False
# 7                6       31.833333        False
# 5                1       31.000000        False
# 4                8       31.000000        False
# 25             311       30.500000        False
# 27              27       30.500000        False
# 26              33       30.500000        False
# 23              30       12.750000        False
# 24             131       12.750000        False
# 22             105       12.750000        False
# 8                9       12.500000        False
# 13              30        8.200000        False
# 14               1        8.200000        False
# 33               1        7.833333        False
# 31             368        7.833333        False
# 32              26        7.833333        False
# 34               5        7.833333        False
# 6                5        4.562500        False
# 1              110        2.400000        False
# 2                1        2.400000        False
# 3                1        2.400000        False
# 0               26        0.333333        False
